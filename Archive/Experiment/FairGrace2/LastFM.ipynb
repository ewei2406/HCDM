# %%
import torch as th
import numpy as np
import pandas as pd
import dgl

# %%
# %%
import argparse

parser = argparse.ArgumentParser()
parser.add_argument('--dataname', type=str, default='LastFM')
parser.add_argument('--gpu', type=int, default=0)
parser.add_argument('--debias_method', type=str, default='r', 
    choices=['opposite', 'opposite-r', 'aug', 'aug-r', 'aug-n', 'opposite-n', 'r', 'none', 'random'],
    help='debiasing method to apply')

parser.add_argument('--debias_attr', type=int, default=1, help='idx of sensitive attribute to be debiased')
parser.add_argument('--num_sens', type=int, default=3, help='# of sensitive attr to make')
parser.add_argument('--reg_weight', type=float, default=20, help='weight for the regularization based debiasing term')  

parser.add_argument('--epochs', type=int, default=200, help='Number of training periods.')
parser.add_argument('--lr', type=float, default=0.001, help='Learning rate.')
parser.add_argument('--wd', type=float, default=1e-5, help='Weight decay.')
parser.add_argument('--temp', type=float, default=1.0, help='Temperature.')

parser.add_argument("--hid_dim", type=int, default=256, help='Hidden layer dim.')
parser.add_argument("--out_dim", type=int, default=256, help='Output layer dim.')

parser.add_argument("--num_layers", type=int, default=2, help='Number of GNN layers.')
parser.add_argument("--seed", type=int, default=100, help='seed')
parser.add_argument('--der1', type=float, default=0.2, help='Drop edge ratio of the 1st augmentation.')

parser.add_argument('--sim_diff_ratio', type=float, default=10, help='Drop feature ratio of the 2nd augmentation.')
parser.add_argument('--enable_heuristic', type=str, default='Y', help='Drop feature ratio of the 2nd augmentation.')


args = parser.parse_args("")

if args.gpu != -1 and th.cuda.is_available():
    args.device = 'cuda:{}'.format(args.gpu)
else:
    args.device = 'cpu'

np.random.seed(args.seed)
th.manual_seed(args.seed)

if args.device != 'cpu':
    th.cuda.manual_seed(args.seed)

# %%
def load_graph_from_file(edge_file: str, feat_file: str, label_file:str=None, disable_header=False) -> dgl.DGLGraph:
  edges = pd.read_csv(edge_file, engine='c')
  edges = th.tensor(edges.to_numpy()).t()
  graph = dgl.graph((edges[0], edges[1]))
  
  if disable_header:
    feat = pd.read_csv(feat_file, header=None, engine='c')
  else:
    feat = pd.read_csv(feat_file, engine='c')

  feat = th.tensor(feat.to_numpy()).int()
  graph.ndata['feat'] = feat

  if label_file:
    labels = pd.read_csv(label_file, engine='c')
    labels = th.tensor(labels.to_numpy())
    graph.ndata['labels'] = labels.t()[1]

  return graph


def add_sens_(graph: dgl.DGLGraph, indices: th.tensor):
  sens = graph.ndata['feat'][:, indices].clone()
  inverse = th.full((graph.num_nodes(),), 1)
  inverse[indices] = 0
  graph.ndata['feat'][indices] = 0
  graph.ndata['sens_attr'] = sens


def calc_weights_(graph: dgl.DGLGraph, debias_attr: int, ratio: int, target: int, location: str='weight'):
  sens = graph.ndata['sens_attr'].t()[debias_attr]
  sim = th.tensor([sens[edge[0]] == sens[edge[1]] for edge in graph.adj().coalesce().indices().t()]).int()
  sim = sim * (ratio - 1)
  sim = sim + 1
  sim = sim * target * sim.shape[0] / sim.sum()
  graph.edata[location] = sim.clamp(0,1)

# %%
graph = load_graph_from_file(
  edge_file=f'./processed_data/{args.dataname}_edge.csv', 
  feat_file=f'./processed_data/{args.dataname}_node_feature.csv', 
  disable_header=True)

add_sens_(graph, graph.ndata['feat'].sum(dim=0).topk(args.num_sens).indices)

if args.debias_method in ['aug', 'aug-r', 'opposite', 'opposite-r']:
  print("augment weight")
  calc_weights_(graph, args.debias_attr, ratio=args.sim_diff_ratio, target=args.der1)
else:
  print("no aug weight")
  calc_weights_(graph, args.debias_attr, ratio=1, target=args.der1)

if args.debias_method in ['opposite', 'opposite-r']:
  print("opposite weight")
  calc_weights_(graph, args.debias_attr, ratio=1 / args.sim_diff_ratio, target=args.der1, location='inv_weight')
# Out:
# no aug weight

# %%
node_attributes = pd.DataFrame(graph.ndata['sens_attr'].numpy())
attribute_list = list(node_attributes.columns)
non_sens_attr_ls = [i for i in attribute_list if i!=args.debias_attr]
non_sens_attr_idx = [i for i in range(len(attribute_list)) if attribute_list[i]!=args.debias_attr]

attr_comb_groups = node_attributes.groupby(attribute_list)
nobias_comb_groups = node_attributes.groupby(non_sens_attr_ls)


attr_comb_groups_map = {tuple(group[1].iloc[0]):list(group[1].index) 
                        for group in attr_comb_groups}
nobias_attr_comb_groups_map = {tuple(group[1].iloc[0][non_sens_attr_ls]):list(group[1].index) 
                            for group in nobias_comb_groups}

print ('Group finished.')
print ('  attr_comb_group_num:', len(attr_comb_groups_map.keys()))
print ('  nobias_attr_comb_group_num:', len(nobias_attr_comb_groups_map.keys()))
# Out:
# Group finished.
#   attr_comb_group_num: 8
#   nobias_attr_comb_group_num: 4

# %%
def aug_weight(graph: dgl.DGLGraph, drop_feat: float, weight: th.Tensor):
  edge_mask = th.bernoulli(weight) == 0
  masked_edges = graph.adj().coalesce().indices()[:, edge_mask]

  new_graph = dgl.graph((masked_edges[0], masked_edges[1])).to(graph.device)

  feat_mask = th.rand((graph.ndata['feat'].shape[1])) < (drop_feat)
  new_graph.ndata['feat'] = graph.ndata['feat'].clone()

  new_graph.ndata['feat'][:, feat_mask] = 0
  new_graph = new_graph.add_self_loop()
  return new_graph

# def aug(graph: dgl.DGLGraph, drop_feat: float, drop_edge: float=0.2):
#   edge_mask = th.bernoulli(th.full((graph.num_edges(),), drop_edge)) == 0
#   masked_edges = graph.adj().coalesce().indices()[:, edge_mask]

#   new_graph = dgl.graph((masked_edges[0], masked_edges[1])).to(graph.device)

#   feat_mask = th.rand((graph.ndata['feat'].shape[1])) < (drop_feat)
#   new_graph.ndata['feat'] = graph.ndata['feat'].clone()

#   new_graph.ndata['feat'][:, feat_mask] = 0
#   new_graph = new_graph.add_self_loop()
#   return new_graph


# aug_weight(graph, 0.2)

# %%
def map_tuple(x, index_ls):
  return tuple([x[idx] for idx in index_ls])

def mem_eff_matmul_mean(mtx1, mtx2):
  mtx1_rows = list(mtx1.shape)[0]
  if mtx1_rows <= 1000:
    return th.mean(th.matmul(mtx1, mtx2))
  else:
    value_sum = 0
    for i in range(mtx1_rows // 1000):
      value_sum += th.sum(th.matmul(mtx1[i*1000:(i+1)*1000, :], mtx2))
    if mtx1_rows % 1000 != 0:
      value_sum += th.sum(th.matmul(mtx1[(i+1)*1000:, :], mtx2))
    return value_sum / (list(mtx1.shape)[0] * list(mtx2.shape)[1])

# %%
import importlib
import model
importlib.reload(model)
import random

import torch.nn as nn

dr = 0.2
# Step 3: Create emb_model =================================================================== #
emb_model = model.Grace(
  in_dim=graph.ndata['feat'].shape[1], 
  hid_dim=args.hid_dim, 
  out_dim=args.out_dim, 
  num_layers=args.num_layers, 
  act_fn=nn.ReLU(), 
  temp=args.temp
)
emb_model = emb_model.to(args.device)

def count_parameters(model):
    return sum([np.prod(p.size()) for p in model.parameters() if p.requires_grad])
print(f'# params: {count_parameters(emb_model)}')

optimizer = th.optim.Adam(emb_model.parameters(), lr=args.lr, weight_decay=args.wd)
noBias = th.full(graph.edata['weight'].shape, 0.2)
# Step 4: Training =======================================================================
if args.debias_method != 'random':
    for epoch in range(args.epochs):
        emb_model.train()
        optimizer.zero_grad()


        if args.debias_method in ['opposite', 'opposite-r']:
            view_1 = aug_weight(graph, drop_feat=dr, weight=graph.edata['weight']).to(args.device)
            view_2 = aug_weight(graph, drop_feat=dr, weight=graph.edata['inv_weight']).to(args.device)
        elif args.debias_method in ['aug-n', 'opposite-n']:
            if args.debias_method == 'aug-n':
                view_1 = aug_weight(graph, drop_feat=dr, weight=graph.edata['weight']).to(args.device)
            else:
                view_1 = aug_weight(graph, drop_feat=dr, weight=graph.edata['inv_weight']).to(args.device)
            view_2 = aug_weight(graph, drop_feat=dr, weight=noBias).to(args.device)
        else:
            view_1 = aug_weight(graph, drop_feat=dr, weight=graph.edata['weight']).to(args.device)
            view_2 = aug_weight(graph, drop_feat=dr, weight=graph.edata['weight']).to(args.device)


        loss = emb_model(view_1, view_2, view_1.ndata['feat'], view_1.ndata['feat'], batch_size=0)
        
        # UGE-R
        if args.debias_method in ['aug-r', 'r', 'opposite-r']:
            h1 = emb_model.encoder(view_1, view_1.ndata['feat'])
            h2 = emb_model.encoder(view_2, view_2.ndata['feat'])
            regu_loss = 0
            scr_groups = random.sample(list(attr_comb_groups_map.keys()), 8)  
            dst_groups = random.sample(list(attr_comb_groups_map.keys()), 8)
            nobias_scr_groups = [map_tuple(group, non_sens_attr_idx) for group in scr_groups]
            nobias_dst_groups = [map_tuple(group, non_sens_attr_idx) for group in dst_groups]

            for group_idx in range(len(scr_groups)):
                for view in [h1, h2]:
                    scr_group_nodes = attr_comb_groups_map[scr_groups[group_idx]]
                    dsc_group_nodes = attr_comb_groups_map[dst_groups[group_idx]]
                    
                    scr_node_embs = view[scr_group_nodes]
                    dsc_node_embs = view[dsc_group_nodes]
                    aver_score = mem_eff_matmul_mean(scr_node_embs, dsc_node_embs.T)

                    nobias_scr_group_nodes = nobias_attr_comb_groups_map[nobias_scr_groups[group_idx]]
                    nobias_dsc_group_nodes = nobias_attr_comb_groups_map[nobias_dst_groups[group_idx]]
                    nobias_scr_node_embs = view[nobias_scr_group_nodes]
                    nobias_dsc_node_embs = view[nobias_dsc_group_nodes]
                    nobias_aver_score = mem_eff_matmul_mean(nobias_scr_node_embs, nobias_dsc_node_embs.T)

                    regu_loss += th.square(aver_score - nobias_aver_score)
                
            print(f"Epoch={epoch:03d}, loss: {loss.item():.2f}, regu_loss: {regu_loss.item():.2f}")

            loss += args.reg_weight * regu_loss
        
        loss.backward()
        optimizer.step()

        print(f'Epoch={epoch:03d}, loss={loss.item():.4f}')

    # Step 5: Linear evaluation ============================================================== #
    graph = graph.add_self_loop().to(args.device)
    embeds = emb_model.get_embedding(graph, graph.ndata['feat'].to(args.device)).cpu()
else:
    embeds = th.rand([graph.num_nodes(), args.out_dim])

graph = graph.to(args.device)
# Out:
# # params: 4278528
# Epoch=000, loss: 9.51, regu_loss: 0.30
# Epoch=000, loss=24.5081
# Epoch=001, loss: 9.47, regu_loss: 0.05
# Epoch=001, loss=12.1533
# Epoch=002, loss: 9.40, regu_loss: 0.20
# Epoch=002, loss=19.1686
# Epoch=003, loss: 9.36, regu_loss: 0.36
# Epoch=003, loss=27.2263
# Epoch=004, loss: 9.34, regu_loss: 0.11
# Epoch=004, loss=14.9877
# Epoch=005, loss: 9.32, regu_loss: 0.13
# Epoch=005, loss=15.8306
# Epoch=006, loss: 9.32, regu_loss: 0.00
# Epoch=006, loss=9.5549
# Epoch=007, loss: 9.30, regu_loss: 0.00
# Epoch=007, loss=9.4785
# Epoch=008, loss: 9.21, regu_loss: 0.01
# Epoch=008, loss=9.5271
# Epoch=009, loss: 9.15, regu_loss: 0.01
# Epoch=009, loss=9.6551
# Epoch=010, loss: 9.10, regu_loss: 0.01
# Epoch=010, loss=9.4350
# Epoch=011, loss: 9.10, regu_loss: 0.00
# Epoch=011, loss=9.2496
# Epoch=012, loss: 9.10, regu_loss: 0.01
# Epoch=012, loss=9.5538
# Epoch=013, loss: 9.09, regu_loss: 0.00
# Epoch=013, loss=9.1670
# Epoch=014, loss: 9.09, regu_loss: 0.00
# Epoch=014, loss=9.2445
# Epoch=015, loss: 9.08, regu_loss: 0.00
# Epoch=015, loss=9.2066
# Epoch=016, loss: 9.09, regu_loss: 0.00
# Epoch=016, loss=9.3269
# Epoch=017, loss: 9.09, regu_loss: 0.01
# Epoch=017, loss=9.6108
# Epoch=018, loss: 9.05, regu_loss: 0.00
# Epoch=018, loss=9.1329
# Epoch=019, loss: 9.04, regu_loss: 0.01
# Epoch=019, loss=9.7564
# Epoch=020, loss: 9.06, regu_loss: 0.01
# Epoch=020, loss=9.6995
# Epoch=021, loss: 9.09, regu_loss: 0.00
# Epoch=021, loss=9.2019
# Epoch=022, loss: 9.12, regu_loss: 0.01
# Epoch=022, loss=9.5066
# Epoch=023, loss: 9.11, regu_loss: 0.01
# Epoch=023, loss=9.4653
# Epoch=024, loss: 9.15, regu_loss: 0.00
# Epoch=024, loss=9.2673
# Epoch=025, loss: 9.12, regu_loss: 0.00
# Epoch=025, loss=9.2880
# Epoch=026, loss: 9.09, regu_loss: 0.00
# Epoch=026, loss=9.2075
# Epoch=027, loss: 9.04, regu_loss: 0.00
# Epoch=027, loss=9.0752
# Epoch=028, loss: 9.04, regu_loss: 0.00
# Epoch=028, loss=9.0717
# Epoch=029, loss: 9.06, regu_loss: 0.00
# Epoch=029, loss=9.1451
# Epoch=030, loss: 9.05, regu_loss: 0.00
# Epoch=030, loss=9.1062
# Epoch=031, loss: 9.03, regu_loss: 0.00
# Epoch=031, loss=9.0448
# Epoch=032, loss: 9.01, regu_loss: 0.00
# Epoch=032, loss=9.0475
# Epoch=033, loss: 8.99, regu_loss: 0.00
# Epoch=033, loss=9.0272
# Epoch=034, loss: 8.97, regu_loss: 0.00
# Epoch=034, loss=9.0155
# Epoch=035, loss: 8.97, regu_loss: 0.00
# Epoch=035, loss=8.9828
# Epoch=036, loss: 8.97, regu_loss: 0.00
# Epoch=036, loss=8.9940
# Epoch=037, loss: 8.94, regu_loss: 0.00
# Epoch=037, loss=8.9454
# Epoch=038, loss: 8.94, regu_loss: 0.00
# Epoch=038, loss=8.9572
# Epoch=039, loss: 8.90, regu_loss: 0.00
# Epoch=039, loss=8.9154
# Epoch=040, loss: 8.92, regu_loss: 0.00
# Epoch=040, loss=8.9320
# Epoch=041, loss: 8.87, regu_loss: 0.00
# Epoch=041, loss=8.9008
# Epoch=042, loss: 8.89, regu_loss: 0.00
# Epoch=042, loss=8.8966
# Epoch=043, loss: 8.87, regu_loss: 0.00
# Epoch=043, loss=8.8831
# Epoch=044, loss: 8.84, regu_loss: 0.00
# Epoch=044, loss=8.8519
# Epoch=045, loss: 8.86, regu_loss: 0.00
# Epoch=045, loss=8.8715
# Epoch=046, loss: 8.87, regu_loss: 0.00
# Epoch=046, loss=8.8819
# Epoch=047, loss: 8.86, regu_loss: 0.00
# Epoch=047, loss=8.8639
# Epoch=048, loss: 8.84, regu_loss: 0.00
# Epoch=048, loss=8.8538
# Epoch=049, loss: 8.85, regu_loss: 0.00
# Epoch=049, loss=8.8685
# Epoch=050, loss: 8.88, regu_loss: 0.00
# Epoch=050, loss=8.8832
# Epoch=051, loss: 8.84, regu_loss: 0.00
# Epoch=051, loss=8.8473
# Epoch=052, loss: 8.83, regu_loss: 0.00
# Epoch=052, loss=8.8435
# Epoch=053, loss: 8.83, regu_loss: 0.00
# Epoch=053, loss=8.8325
# Epoch=054, loss: 8.82, regu_loss: 0.00
# Epoch=054, loss=8.8339
# Epoch=055, loss: 8.84, regu_loss: 0.00
# Epoch=055, loss=8.8497
# Epoch=056, loss: 8.83, regu_loss: 0.00
# Epoch=056, loss=8.8447
# Epoch=057, loss: 8.83, regu_loss: 0.00
# Epoch=057, loss=8.8353
# Epoch=058, loss: 8.81, regu_loss: 0.00
# Epoch=058, loss=8.8218
# Epoch=059, loss: 8.82, regu_loss: 0.00
# Epoch=059, loss=8.8275
# Epoch=060, loss: 8.81, regu_loss: 0.00
# Epoch=060, loss=8.8438
# Epoch=061, loss: 8.81, regu_loss: 0.00
# Epoch=061, loss=8.8203
# Epoch=062, loss: 8.83, regu_loss: 0.00
# Epoch=062, loss=8.8485
# Epoch=063, loss: 8.81, regu_loss: 0.00
# Epoch=063, loss=8.8239
# Epoch=064, loss: 8.81, regu_loss: 0.00
# Epoch=064, loss=8.8165
# Epoch=065, loss: 8.83, regu_loss: 0.00
# Epoch=065, loss=8.8459
# Epoch=066, loss: 8.80, regu_loss: 0.00
# Epoch=066, loss=8.8191
# Epoch=067, loss: 8.81, regu_loss: 0.00
# Epoch=067, loss=8.8112
# Epoch=068, loss: 8.82, regu_loss: 0.00
# Epoch=068, loss=8.8270
# Epoch=069, loss: 8.80, regu_loss: 0.00
# Epoch=069, loss=8.8040
# Epoch=070, loss: 8.79, regu_loss: 0.00
# Epoch=070, loss=8.8008
# Epoch=071, loss: 8.80, regu_loss: 0.00
# Epoch=071, loss=8.8064
# Epoch=072, loss: 8.81, regu_loss: 0.00
# Epoch=072, loss=8.8122
# Epoch=073, loss: 8.79, regu_loss: 0.00
# Epoch=073, loss=8.8020
# Epoch=074, loss: 8.80, regu_loss: 0.00
# Epoch=074, loss=8.8008
# Epoch=075, loss: 8.79, regu_loss: 0.00
# Epoch=075, loss=8.7968
# Epoch=076, loss: 8.79, regu_loss: 0.00
# Epoch=076, loss=8.7927
# Epoch=077, loss: 8.80, regu_loss: 0.00
# Epoch=077, loss=8.8081
# Epoch=078, loss: 8.80, regu_loss: 0.00
# Epoch=078, loss=8.8040
# Epoch=079, loss: 8.79, regu_loss: 0.00
# Epoch=079, loss=8.7918
# Epoch=080, loss: 8.80, regu_loss: 0.00
# Epoch=080, loss=8.8014
# Epoch=081, loss: 8.79, regu_loss: 0.00
# Epoch=081, loss=8.8008
# Epoch=082, loss: 8.78, regu_loss: 0.00
# Epoch=082, loss=8.7842
# Epoch=083, loss: 8.78, regu_loss: 0.00
# Epoch=083, loss=8.7932
# Epoch=084, loss: 8.78, regu_loss: 0.00
# Epoch=084, loss=8.7862
# Epoch=085, loss: 8.81, regu_loss: 0.00
# Epoch=085, loss=8.8124
# Epoch=086, loss: 8.80, regu_loss: 0.00
# Epoch=086, loss=8.8040
# Epoch=087, loss: 8.78, regu_loss: 0.00
# Epoch=087, loss=8.7833
# Epoch=088, loss: 8.79, regu_loss: 0.00
# Epoch=088, loss=8.7945
# Epoch=089, loss: 8.78, regu_loss: 0.00
# Epoch=089, loss=8.7888
# Epoch=090, loss: 8.77, regu_loss: 0.00
# Epoch=090, loss=8.7793
# Epoch=091, loss: 8.78, regu_loss: 0.00
# Epoch=091, loss=8.7832
# Epoch=092, loss: 8.77, regu_loss: 0.00
# Epoch=092, loss=8.7825
# Epoch=093, loss: 8.78, regu_loss: 0.00
# Epoch=093, loss=8.7858
# Epoch=094, loss: 8.78, regu_loss: 0.00
# Epoch=094, loss=8.7830
# Epoch=095, loss: 8.77, regu_loss: 0.00
# Epoch=095, loss=8.7797
# Epoch=096, loss: 8.77, regu_loss: 0.00
# Epoch=096, loss=8.7826
# Epoch=097, loss: 8.77, regu_loss: 0.00
# Epoch=097, loss=8.7762
# Epoch=098, loss: 8.77, regu_loss: 0.00
# Epoch=098, loss=8.7795
# Epoch=099, loss: 8.78, regu_loss: 0.00
# Epoch=099, loss=8.7816
# Epoch=100, loss: 8.78, regu_loss: 0.00
# Epoch=100, loss=8.7848
# Epoch=101, loss: 8.79, regu_loss: 0.00
# Epoch=101, loss=8.7919
# Epoch=102, loss: 8.77, regu_loss: 0.00
# Epoch=102, loss=8.7700
# Epoch=103, loss: 8.77, regu_loss: 0.00
# Epoch=103, loss=8.7716
# Epoch=104, loss: 8.77, regu_loss: 0.00
# Epoch=104, loss=8.7779
# Epoch=105, loss: 8.77, regu_loss: 0.00
# Epoch=105, loss=8.7749
# Epoch=106, loss: 8.76, regu_loss: 0.00
# Epoch=106, loss=8.7717
# Epoch=107, loss: 8.77, regu_loss: 0.00
# Epoch=107, loss=8.7700
# Epoch=108, loss: 8.77, regu_loss: 0.00
# Epoch=108, loss=8.7689
# Epoch=109, loss: 8.77, regu_loss: 0.00
# Epoch=109, loss=8.7759
# Epoch=110, loss: 8.77, regu_loss: 0.00
# Epoch=110, loss=8.7676
# Epoch=111, loss: 8.77, regu_loss: 0.00
# Epoch=111, loss=8.7738
# Epoch=112, loss: 8.77, regu_loss: 0.00
# Epoch=112, loss=8.7741
# Epoch=113, loss: 8.77, regu_loss: 0.00
# Epoch=113, loss=8.7776
# Epoch=114, loss: 8.76, regu_loss: 0.00
# Epoch=114, loss=8.7676
# Epoch=115, loss: 8.78, regu_loss: 0.00
# Epoch=115, loss=8.7788
# Epoch=116, loss: 8.79, regu_loss: 0.00
# Epoch=116, loss=8.7893
# Epoch=117, loss: 8.78, regu_loss: 0.00
# Epoch=117, loss=8.7849
# Epoch=118, loss: 8.77, regu_loss: 0.00
# Epoch=118, loss=8.7740
# Epoch=119, loss: 8.77, regu_loss: 0.00
# Epoch=119, loss=8.7755
# Epoch=120, loss: 8.77, regu_loss: 0.00
# Epoch=120, loss=8.7786
# Epoch=121, loss: 8.78, regu_loss: 0.00
# Epoch=121, loss=8.7818
# Epoch=122, loss: 8.76, regu_loss: 0.00
# Epoch=122, loss=8.7624
# Epoch=123, loss: 8.76, regu_loss: 0.00
# Epoch=123, loss=8.7653
# Epoch=124, loss: 8.78, regu_loss: 0.00
# Epoch=124, loss=8.7805
# Epoch=125, loss: 8.77, regu_loss: 0.00
# Epoch=125, loss=8.7789
# Epoch=126, loss: 8.78, regu_loss: 0.00
# Epoch=126, loss=8.7813
# Epoch=127, loss: 8.76, regu_loss: 0.00
# Epoch=127, loss=8.7657
# Epoch=128, loss: 8.77, regu_loss: 0.00
# Epoch=128, loss=8.7711
# Epoch=129, loss: 8.77, regu_loss: 0.00
# Epoch=129, loss=8.7772
# Epoch=130, loss: 8.77, regu_loss: 0.00
# Epoch=130, loss=8.7698
# Epoch=131, loss: 8.76, regu_loss: 0.00
# Epoch=131, loss=8.7659
# Epoch=132, loss: 8.76, regu_loss: 0.00
# Epoch=132, loss=8.7622
# Epoch=133, loss: 8.76, regu_loss: 0.00
# Epoch=133, loss=8.7632
# Epoch=134, loss: 8.78, regu_loss: 0.00
# Epoch=134, loss=8.7786
# Epoch=135, loss: 8.76, regu_loss: 0.00
# Epoch=135, loss=8.7672
# Epoch=136, loss: 8.77, regu_loss: 0.00
# Epoch=136, loss=8.7731
# Epoch=137, loss: 8.76, regu_loss: 0.00
# Epoch=137, loss=8.7651
# Epoch=138, loss: 8.76, regu_loss: 0.00
# Epoch=138, loss=8.7665
# Epoch=139, loss: 8.78, regu_loss: 0.00
# Epoch=139, loss=8.7798
# Epoch=140, loss: 8.77, regu_loss: 0.00
# Epoch=140, loss=8.7703
# Epoch=141, loss: 8.77, regu_loss: 0.00
# Epoch=141, loss=8.7713
# Epoch=142, loss: 8.77, regu_loss: 0.00
# Epoch=142, loss=8.7755
# Epoch=143, loss: 8.76, regu_loss: 0.00
# Epoch=143, loss=8.7719
# Epoch=144, loss: 8.76, regu_loss: 0.00
# Epoch=144, loss=8.7652
# Epoch=145, loss: 8.77, regu_loss: 0.00
# Epoch=145, loss=8.7709
# Epoch=146, loss: 8.76, regu_loss: 0.00
# Epoch=146, loss=8.7667
# Epoch=147, loss: 8.77, regu_loss: 0.00
# Epoch=147, loss=8.7751
# Epoch=148, loss: 8.75, regu_loss: 0.00
# Epoch=148, loss=8.7571
# Epoch=149, loss: 8.76, regu_loss: 0.00
# Epoch=149, loss=8.7648
# Epoch=150, loss: 8.77, regu_loss: 0.00
# Epoch=150, loss=8.7739
# Epoch=151, loss: 8.77, regu_loss: 0.00
# Epoch=151, loss=8.7664
# Epoch=152, loss: 8.77, regu_loss: 0.00
# Epoch=152, loss=8.7768
# Epoch=153, loss: 8.76, regu_loss: 0.00
# Epoch=153, loss=8.7676
# Epoch=154, loss: 8.77, regu_loss: 0.00
# Epoch=154, loss=8.7762
# Epoch=155, loss: 8.76, regu_loss: 0.00
# Epoch=155, loss=8.7658
# Epoch=156, loss: 8.76, regu_loss: 0.00
# Epoch=156, loss=8.7697
# Epoch=157, loss: 8.77, regu_loss: 0.00
# Epoch=157, loss=8.7722
# Epoch=158, loss: 8.77, regu_loss: 0.00
# Epoch=158, loss=8.7727
# Epoch=159, loss: 8.76, regu_loss: 0.00
# Epoch=159, loss=8.7633
# Epoch=160, loss: 8.76, regu_loss: 0.00
# Epoch=160, loss=8.7597
# Epoch=161, loss: 8.76, regu_loss: 0.00
# Epoch=161, loss=8.7672
# Epoch=162, loss: 8.76, regu_loss: 0.00
# Epoch=162, loss=8.7597
# Epoch=163, loss: 8.75, regu_loss: 0.00
# Epoch=163, loss=8.7554
# Epoch=164, loss: 8.75, regu_loss: 0.00
# Epoch=164, loss=8.7540
# Epoch=165, loss: 8.76, regu_loss: 0.00
# Epoch=165, loss=8.7645
# Epoch=166, loss: 8.76, regu_loss: 0.00
# Epoch=166, loss=8.7637
# Epoch=167, loss: 8.75, regu_loss: 0.00
# Epoch=167, loss=8.7562
# Epoch=168, loss: 8.75, regu_loss: 0.00
# Epoch=168, loss=8.7559
# Epoch=169, loss: 8.75, regu_loss: 0.00
# Epoch=169, loss=8.7571
# Epoch=170, loss: 8.75, regu_loss: 0.00
# Epoch=170, loss=8.7537
# Epoch=171, loss: 8.75, regu_loss: 0.00
# Epoch=171, loss=8.7534
# Epoch=172, loss: 8.75, regu_loss: 0.00
# Epoch=172, loss=8.7525
# Epoch=173, loss: 8.75, regu_loss: 0.00
# Epoch=173, loss=8.7566
# Epoch=174, loss: 8.76, regu_loss: 0.00
# Epoch=174, loss=8.7627
# Epoch=175, loss: 8.75, regu_loss: 0.00
# Epoch=175, loss=8.7528
# Epoch=176, loss: 8.75, regu_loss: 0.00
# Epoch=176, loss=8.7548
# Epoch=177, loss: 8.75, regu_loss: 0.00
# Epoch=177, loss=8.7524
# Epoch=178, loss: 8.76, regu_loss: 0.00
# Epoch=178, loss=8.7607
# Epoch=179, loss: 8.75, regu_loss: 0.00
# Epoch=179, loss=8.7496
# Epoch=180, loss: 8.75, regu_loss: 0.00
# Epoch=180, loss=8.7545
# Epoch=181, loss: 8.76, regu_loss: 0.00
# Epoch=181, loss=8.7671
# Epoch=182, loss: 8.75, regu_loss: 0.00
# Epoch=182, loss=8.7588
# Epoch=183, loss: 8.75, regu_loss: 0.00
# Epoch=183, loss=8.7535
# Epoch=184, loss: 8.75, regu_loss: 0.00
# Epoch=184, loss=8.7547
# Epoch=185, loss: 8.76, regu_loss: 0.00
# Epoch=185, loss=8.7589
# Epoch=186, loss: 8.76, regu_loss: 0.00
# Epoch=186, loss=8.7635
# Epoch=187, loss: 8.75, regu_loss: 0.00
# Epoch=187, loss=8.7536
# Epoch=188, loss: 8.75, regu_loss: 0.00
# Epoch=188, loss=8.7570
# Epoch=189, loss: 8.76, regu_loss: 0.00
# Epoch=189, loss=8.7569
# Epoch=190, loss: 8.75, regu_loss: 0.00
# Epoch=190, loss=8.7561
# Epoch=191, loss: 8.75, regu_loss: 0.00
# Epoch=191, loss=8.7551
# Epoch=192, loss: 8.75, regu_loss: 0.00
# Epoch=192, loss=8.7533
# Epoch=193, loss: 8.75, regu_loss: 0.00
# Epoch=193, loss=8.7507
# Epoch=194, loss: 8.76, regu_loss: 0.00
# Epoch=194, loss=8.7676
# Epoch=195, loss: 8.76, regu_loss: 0.00
# Epoch=195, loss=8.7570
# Epoch=196, loss: 8.75, regu_loss: 0.00
# Epoch=196, loss=8.7545
# Epoch=197, loss: 8.75, regu_loss: 0.00
# Epoch=197, loss=8.7548
# Epoch=198, loss: 8.75, regu_loss: 0.00
# Epoch=198, loss=8.7504
# Epoch=199, loss: 8.75, regu_loss: 0.00
# Epoch=199, loss=8.7527

# %%
from sklearn.metrics import f1_score
from sklearn.linear_model import LogisticRegression

def get_f1(embeds, graph, debias_attr):
  evaluate_attr = graph.ndata['sens_attr'][:,debias_attr]
  split_idx = int(graph.num_nodes() * 0.75)
  lgreg = LogisticRegression(
    random_state=0, 
    class_weight='balanced', 
    max_iter=500).fit(
    embeds[:split_idx].cpu(), evaluate_attr[:split_idx].cpu())
  pred = lgreg.predict(embeds[split_idx:].cpu())

  score = f1_score(evaluate_attr[split_idx:split_idx + pred.shape[0]].cpu(), pred, average='micro')

  print(f'-- micro-f1 when predicting sensitive attr #{debias_attr}: {score}')
  return score
  

def dcg_at_k(r, k):
    r = np.asfarray(r)[:k]
    if r.size != k:
        raise ValueError('Ranking List length < k')    
    return np.sum((2**r - 1) / np.log2(np.arange(2, r.size + 2)))


def ndcg_at_k(r, k):
    sort_r = sorted(r,reverse = True)
    idcg = dcg_at_k(sort_r, k)
    if not idcg:
        print('.', end=' ')
        return 0.
    return dcg_at_k(r, k) / idcg


def eval_link_ndcg(embeds, graph: dgl.DGLGraph):
  embeds = embeds.cpu()
  graph = graph.cpu().remove_self_loop()
  accum_ndcg = 0
  node_cnt = 0
  sample_size = int(min(graph.num_nodes() / 25, 75))
  k = int(min(sample_size / 5, 10))
  adj = graph.adj().to_dense() # n x n tensor

  for node in graph.nodes(): # node is an int
    node_edges = adj[node] # nth row
    positive_nodes = node_edges.nonzero(as_tuple=True)[0] # indices where there is a 1
    split_idx = int(positive_nodes.shape[0] / 10) + 1 # 90 - 10 split of edges

    if split_idx == 0 or split_idx > sample_size:
      continue
      
    negative_nodes = np.random.choice(
      (1 - node_edges).nonzero(as_tuple=True)[0], # 1 where there is no edge
      sample_size - split_idx,
      replace=False
    )
    
    positive_nodes = positive_nodes[:split_idx] # Subset of positive pair
    eval_nodes = np.concatenate((positive_nodes, negative_nodes))
    eval_edges = np.zeros(sample_size)
    eval_edges[:split_idx] = 1

    predicted_edges = np.dot(embeds[node], embeds[eval_nodes].T)
    rank_pred_keys = np.argsort(predicted_edges)[::-1]
    ranked_node_edges = eval_edges[rank_pred_keys]
    ndcg = ndcg_at_k(ranked_node_edges, k)
    accum_ndcg += ndcg

    node_cnt += 1

  score = accum_ndcg/node_cnt
  print(f'-- ndcg of link prediction: {score:.6f}')
  return score

# %%
results = {
  "dataname": args.dataname,
  "debias_method": args.debias_method,
  "epochs": args.epochs,
  "seed": args.seed,
  "debias_attr": args.debias_attr,
  "reg_weight": args.reg_weight,
  "temp": args.temp,
  "der1": args.der1,
  "heuristic_drop": args.enable_heuristic,
  "ratio": args.sim_diff_ratio
}

graph = graph.remove_self_loop()
for attr_idx in range(0, graph.ndata['sens_attr'].shape[1]):
  results[f'f1_{attr_idx}'] = get_f1(embeds, graph, attr_idx)
results['link'] = eval_link_ndcg(embeds, graph)
# Out:
# -- micro-f1 when predicting sensitive attr #0: 0.75498426023085
# -- micro-f1 when predicting sensitive attr #1: 0.7082896117523609
# -- micro-f1 when predicting sensitive attr #2: 0.670514165792235
# -- ndcg of link prediction: 0.344125

# %%
# randEmbeds = th.randn_like(embeds)

# for attr_idx in range(0, graph.ndata['sens_attr'].shape[1]):
#   results[f'f1_{attr_idx}'] = get_f1(randEmbeds, graph, attr_idx)
# results['link'] = eval_link_ndcg(randEmbeds, graph)

# %%
import sys
sys.path.append(os.path.join('../..'))
import Utils.Export as Export
Export.saveData('./results_H.csv', results)
